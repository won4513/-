# %% [markdown]
# # 종합실습2 이변량분석(y-숫자) : car seat 매출 분석

# %% [markdown]
# * 카시트에 대해서 지역 매장 별 매출액을 예측하고자 합니다.

# %% [markdown]
# ![](https://cdn.images.express.co.uk/img/dynamic/24/590x/child-car-seat-986556.jpg?r=1532946857754)

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as spst

# %% [markdown]
# ### (2) 데이터 로딩

# %% [markdown]
# |	변수명	|	설명	|	구분	|
# |	----	|	----	|	----	|
# |	Sales 	|	 각 지역 판매량(단위 : 1000개)	|	Target	|
# |	CompPrice 	|	지역별 경쟁사 판매가격(달러)	|	feature	|
# |	Advertising 	|	 각 지역, 회사의 광고 예산(단위 : 1000달러)	|	feature	|
# |	Population 	|	 지역 인구수(단위 : 1000명)	|	feature	|
# |	Price 	|	 자사 지역별 판매가격(달러)	|	feature	|
# |	ShelveLoc 	|	 진열상태	|	feature	|
# |	Age 	|	 지역 인구의 평균 연령	|	feature	|
# |	US 	|	 매장이 미국에 있는지 여부	|	feature	|
# |	Income 	|	 지역 주민 평균 소득	|	feature	|
# |	Urban 	|	 매장이 도시에 있는지 여부	|	feature	|

# %%
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/Carseats2.csv'
data = pd.read_csv(path)
data.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#   Urban   US
# 0   Yes  Yes
# 1   Yes  Yes
# 2   Yes  Yes
# 3   Yes  Yes
# 4   Yes   No

# %%
target = 'Sales'

# %% [markdown]
# ## 1.숫자형 X --> Y

# %% [markdown]
# * 모든 숫자형 X에 대해서 Y와 비교하여 차트를 그리고 수치화 하시오.
#
# ① 시각화 : scatter, jointplot
# ② 수치화 : 상관분석

# %%
#함수화
def eda2_n(data, target, var):
    sns.scatterplot(x = var, y = target, data = data)
    plt.show()

    result = spst.pearsonr(data[var], data[target])
    print(f'상관계수 : {result[0]}, p-value : {result[1]}')

# %% [markdown]
# ### (1) Advertising -> Sales

# %% [markdown]
# 1) 시각화 : scatter(regplot), jointplot

# %%
var = 'Advertising'

sns.scatterplot(x=var, y = target, data = data)
plt.show()

# %%
sns.regplot(x=var, y = target, data = data)
plt.show()

# %%
sns.jointplot(x=var, y = target, data = data)
plt.show()

# %% [markdown]
# 2) 수치화 : 상관분석

# %%
result = spst.pearsonr(data[var], data[target])
print(f'상관계수 : {result[0]}, p-value : {result[1]}')
# Out:
# 상관계수 : 0.2695067813769019, p-value : 4.377677110302732e-08

# %% [markdown]
# 3) 시각화와 수치화 결과로부터 파악한 내용을 적어 봅시다.

# %% [markdown]
# ### (2) Population -> Sales

# %% [markdown]
# 1) 시각화 : scatter

# %%
var = 'Population'
sns.scatterplot(x = var, y = target, data = data)
plt.show()

# %%
var = 'Population'
sns.regplot(x = var, y = target, data = data)
plt.show()

# %%
var = 'Population'
sns.jointplot(x = var, y = target, data = data)
plt.show()

# %% [markdown]
# 2) 수치화 : 상관분석

# %%
spst.pearsonr(data[var], data[target])
# Out:
# (0.050470984472039196, 0.31398160931903)

# %% [markdown]
# 3) 시각화와 수치화 결과로부터 파악한 내용을 적어 봅시다.

# %% [markdown]
# 인구수와 판매량은 상관관계가 없다

# %% [markdown]
# ### (3) Price -> Sales

# %% [markdown]
# 1) 시각화 : scatter

# %%
var = 'Price'
sns.scatterplot(x = var, y = target, data = data)
plt.show()

# %%
var = 'Price'
sns.regplot(x = var, y = target, data = data)
plt.show()

# %%
var = 'Price'
sns.jointplot(x = var, y = target, data = data)
plt.show()

# %% [markdown]
# 2) 수치화 : 상관분석

# %%
spst.pearsonr(data[var], data[target])
# Out:
# (-0.44495072784657264, 7.618187011912723e-21)

# %% [markdown]
# 3) 시각화와 수치화 결과로부터 파악한 내용을 적어 봅시다.

# %% [markdown]
# ### (4) Age -> Sales

# %% [markdown]
# 1) 시각화 : scatter

# %% [markdown]
# 2) 수치화 : 상관분석

# %% [markdown]
# 3) 시각화와 수치화 결과로부터 파악한 내용을 적어 봅시다.

# %% [markdown]
# ### (5) CompPrice -> Sales

# %% [markdown]
# 1) 시각화 : scatter

# %% [markdown]
# 2) 수치화 : 상관분석

# %% [markdown]
# 3) 시각화와 수치화 결과로부터 파악한 내용을 적어 봅시다.

# %% [markdown]
# ### (6) Income -> Sales

# %% [markdown]
# 1) 시각화 : scatter

# %% [markdown]
# 2) 수치화 : 상관분석

# %% [markdown]
# 3) 시각화와 수치화 결과로부터 파악한 내용을 적어 봅시다.

# %%
eda2_n(data, 'Sales', 'Price')
# Out:
# 상관계수 : -0.44495072784657264, p-value : 7.618187011912723e-21

# %%
eda2_n(data, 'Sales', 'CompPrice')
# Out:
# 상관계수 : 0.06407872955062151, p-value : 0.2009398289418295

# %% [markdown]
# ## 2.범주형 X --> Y

# %% [markdown]
# * 모든 범자형 X에 대해서 Y와 비교하여 차트를 그리고 수치화 하시오.
#
# ① 시각화 : 평균비교 barplot
# ② 수치화 : t-test, anova

# %% [markdown]
# ### (1) ShelveLoc-> Sales

# %% [markdown]
# 1) 시각화 : 평균비교 barplot

# %%
var = 'ShelveLoc'

sns.barplot(x=var, y=target, data = data)
plt.show()

# %% [markdown]
# 2) 수치화 : t-test, anova

# %%
d_b = data.loc[data[var]=='Bad', target]
d_m = data.loc[data[var]=='Medium', target]
d_g = data.loc[data[var]=='Good', target]

spst.f_oneway(d_b, d_m, d_g)
# Out:
# F_onewayResult(statistic=92.22990509910348, pvalue=1.26693609015938e-33)

# %% [markdown]
# 3) 시각화와 수치화 결과로부터 파악한 내용을 적어 봅시다.

# %% [markdown]
# ### (2) Urban -> Sales

# %% [markdown]
# 1) 시각화 : 평균비교 barplot

# %%
var = 'Urban'

sns.barplot(x=var, y=target, data = data)
plt.show()

# %% [markdown]
# 2) 수치화 : t-test, anova

# %%
U_y = data.loc[data[var]=='Yes', target]
U_n = data.loc[data[var]=='No', target]

spst.ttest_ind(U_y,U_n)
# Out:
# Ttest_indResult(statistic=-0.30765346670661126, pvalue=0.7585069603942775)

# %% [markdown]
# 3) 시각화와 수치화 결과로부터 파악한 내용을 적어 봅시다.

# %% [markdown]
# 매장이 도시에 있는지 여부와 판매량과의 상관관계는 유의미하지 않다

# %% [markdown]
# ### (3) US-> Sales

# %% [markdown]
# 1) 시각화 : 평균비교 barplot

# %%
var = 'US'

sns.barplot(x=var, y=target, data = data)
plt.show()

# %% [markdown]
# 2) 수치화 : t-test, anova

# %%
Us_y = data.loc[data[var]=='Yes', target]
Us_n = data.loc[data[var]=='No', target]

spst.ttest_ind(Us_y,Us_n)
# Out:
# Ttest_indResult(statistic=3.589738747802499, pvalue=0.00037233958701471517)

# %% [markdown]
# 3) 시각화와 수치화 결과로부터 파악한 내용을 적어 봅시다.

# %% [markdown]
# 매장이 미국에 있는지 여부와 판매량은 약한 상관관계가 있다

# %% [markdown]
# ## 3.관계 정리하기

# %% [markdown]
# ① 강한관계

# %% [markdown]
# ② 중간관계

# %% [markdown]
# ③ 관계없음
